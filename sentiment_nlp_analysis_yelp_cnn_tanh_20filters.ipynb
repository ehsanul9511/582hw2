# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/hw2
# Out:
# /content/drive/MyDrive/hw2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Dropout, SpatialDropout1D
from tensorflow.keras.callbacks import EarlyStopping
from nltk.corpus import stopwords

# %%
# Read the input text file into a DataFrame
df = pd.read_csv('data.txt')
df = df.sample(frac=1)

# %%
df = df.drop(columns=['Unnamed: 0'])

no_neutral = False

df = df.rename(columns={'text':'review', 'stars':'sentiment'})

if no_neutral:
    df = df[df['sentiment']!=3]
    df['sentiment'] = df['sentiment'].apply(lambda x: int(x>3))
else:
    df['sentiment'] = df['sentiment'].apply(lambda x: np.sign(x-3)+1)

# %%
from tensorflow.keras.utils import to_categorical

label = df.sentiment
label.unique()
num_classes = len(set(label))
one_hot_labels = to_categorical(label, num_classes=num_classes)

# %%
from gensim.parsing.porter import PorterStemmer
from gensim.utils import simple_preprocess
# Tokenize the text column to get the new column 'tokenized_text'
porter_stemmer = PorterStemmer()
review = df.review.values
review = [simple_preprocess(line, deacc=True) for line in review] 
review = [[porter_stemmer.stem(word) for word in tokens] for tokens in review]
tokenizer = Tokenizer(num_words=5000, lower=True)
tokenizer.fit_on_texts(review)
sequences = tokenizer.texts_to_sequences(review)

# %%
vocab_size = len(tokenizer.word_index)+1
vocab_size
# Out:
# 26781

# %%
maxlen = 200
padded_sequences = pad_sequences(sequences, maxlen=maxlen)

# %%
from sklearn.model_selection import train_test_split
#split data into training and testing
padded_sequences, test_padded_sequences = train_test_split(padded_sequences, test_size=0.2, shuffle=False)
one_hot_labels, test_one_hot_labels = train_test_split(one_hot_labels, test_size=0.2, shuffle=False)

# %%
print(tokenizer.word_index)
# Out:
# {'the': 1, 'and': 2, 'to': 3, 'wa': 4, 'it': 5, 'of': 6, 'for': 7, 'is': 8, 'in': 9, 'on': 10, 'that': 11, 'we': 12, 'but': 13, 'my': 14, 'thei': 15, 'with': 16, 'thi': 17, 'not': 18, 'you': 19, 'have': 20, 'were': 21, 'had': 22, 'food': 23, 'at': 24, 'be': 25, 'so': 26, 'good': 27, 'place': 28, 'ar': 29, 'there': 30, 'as': 31, 'order': 32, 'time': 33, 'like': 34, 'veri': 35, 'if': 36, 'our': 37, 'out': 38, 'go': 39, 'me': 40, 'get': 41, 'just': 42, 'all': 43, 'servic': 44, 'great': 45, 'here': 46, 'would': 47, 'us': 48, 'when': 49, 'or': 50, 'up': 51, 'their': 52, 'back': 53, 'from': 54, 'an': 55, 'about': 56, 'no': 57, 'which': 58, 'can': 59, 'realli': 60, 'she': 61, 'what': 62, 'will': 63, 'been': 64, 'some': 65, 'more': 66, 'he': 67, 'onli': 68, 'other': 69, 'wait': 70, 'got': 71, 'becaus': 72, 'even': 73, 'also': 74, 'restaur': 75, 'them': 76, 'do': 77, 'don': 78, 'nice': 79, 'come': 80, 'by': 81, 'your': 82, 'look': 83, 'want': 84, 've': 85, 'after': 86, 'price': 87, 'too': 88, 'ask': 89, 'try': 90, 'didn': 91, 'make': 92, 'came': 93, 'love': 94, 'tabl': 95, 'well': 96, 'did': 97, 'drink': 98, 'than': 99, 'ha': 100, 'could': 101, 'over': 102, 'chicken': 103, 'littl': 104, 'staff': 105, 'tast': 106, 'never': 107, 'much': 108, 'menu': 109, 'first': 110, 'went': 111, 'fri': 112, 'eat': 113, 'pretti': 114, 'peopl': 115, 'again': 116, 'dai': 117, 'better': 118, 'bar': 119, 'best': 120, 'minut': 121, 'then': 122, 'sai': 123, 'said': 124, 'take': 125, 'thing': 126, 'experi': 127, 'need': 128, 'know': 129, 'two': 130, 'star': 131, 'room': 132, 'wai': 133, 'give': 134, 'friendli': 135, 'her': 136, 'night': 137, 'work': 138, 'off': 139, 'think': 140, 'who': 141, 'alwai': 142, 'made': 143, 'pizza': 144, 'how': 145, 'new': 146, 'befor': 147, 'burger': 148, 'sauc': 149, 'seem': 150, 'definit': 151, 'locat': 152, 'flavor': 153, 'hour': 154, 'ani': 155, 'wasn': 156, 're': 157, 'chees': 158, 'call': 159, 'meal': 160, 'lot': 161, 'bad': 162, 'down': 163, 'custom': 164, 'friend': 165, 'still': 166, 'delici': 167, 'review': 168, 'while': 169, 'around': 170, 'area': 171, 'took': 172, 'told': 173, 'walk': 174, 'anoth': 175, 'salad': 176, 'am': 177, 'seat': 178, 'busi': 179, 'beer': 180, 'few': 181, 'recommend': 182, 'see': 183, 'server': 184, 'right': 185, 'check': 186, 'bit': 187, 'sure': 188, 'small': 189, 'lunch': 190, 'visit': 191, 'disappoint': 192, 'side': 193, 'ever': 194, 'though': 195, 'serv': 196, 'sandwich': 197, 'ok': 198, 'someth': 199, 'dish': 200, 'feel': 201, 'fresh': 202, 'manag': 203, 'next': 204, 'last': 205, 'find': 206, 'mani': 207, 'noth': 208, 'long': 209, 'll': 210, 'enjoi': 211, 'expect': 212, 'sinc': 213, 'now': 214, 'most': 215, 'dinner': 216, 'year': 217, 'amaz': 218, 'everyth': 219, 'clean': 220, 'should': 221, 'help': 222, 'top': 223, 'special': 224, 'tri': 225, 'cook': 226, 'where': 227, 'howev': 228, 'into': 229, 'open': 230, 'hotel': 231, 'both': 232, 'everi': 233, 'coffe': 234, 'stai': 235, 'hi': 236, 'waitress': 237, 'hot': 238, 'differ': 239, 'left': 240, 'offer': 241, 'breakfast': 242, 'store': 243, 'home': 244, 'end': 245, 'worth': 246, 'same': 247, 'roll': 248, 'reason': 249, 'start': 250, 'person': 251, 'stop': 252, 'enough': 253, 'sit': 254, 'bread': 255, 'park': 256, 'actual': 257, 'awai': 258, 'meat': 259, 'probabl': 260, 'pai': 261, 'close': 262, 'big': 263, 'shrimp': 264, 'overal': 265, 'return': 266, 'qualiti': 267, 'mayb': 268, 'put': 269, 'atmospher': 270, 'why': 271, 'sweet': 272, 'select': 273, 'decent': 274, 'anyth': 275, 'line': 276, 'option': 277, 'onc': 278, 'happi': 279, 'taco': 280, 'half': 281, 'let': 282, 'item': 283, 'kind': 284, 'arriv': 285, 'decid': 286, 'thought': 287, 'tasti': 288, 'car': 289, 'spot': 290, 'els': 291, 'tell': 292, 'old': 293, 'water': 294, 'gui': 295, 'super': 296, 'awesom': 297, 'excel': 298, 'portion': 299, 'favorit': 300, 'ic': 301, 'live': 302, 'these': 303, 'week': 304, 'found': 305, 'plate': 306, 'final': 307, 'sushi': 308, 'full': 309, 'usual': 310, 'quit ...

# %%
print(review[0])
print(sequences[0])
# Out:
# ['would', 'realli', 'like', 'to', 'try', 'thi', 'place', 'but', 'everi', 'time', 'show', 'up', 'thei', 'ar', 'unexpectedli', 'close', 'the', 'first', 'time', 'show', 'up', 'wa', 'told', 'thei', 'were', 'close', 'for', 'spring', 'spruce', 'up', 'and', 'would', 'be', 'open', 'on', 'the', 'th', 'left', 'littl', 'annoi', 'becaus', 'there', 'wa', 'no', 'indic', 'of', 'thi', 'on', 'their', 'websit', 'which', 'had', 'us', 'to', 'look', 'them', 'up', 'and', 'brows', 'the', 'menu', 'later', 'discov', 'thei', 'had', 'someth', 'up', 'on', 'their', 'facebook', 'page', 'about', 'be', 'close', 'but', 'see', 'as', 'those', 'don', 'have', 'facebook', 'thi', 'wa', 'of', 'no', 'benefit', 'to', 'me', 'todai', 'march', 'th', 'drove', 'all', 'the', 'wai', 'over', 'onli', 'to', 'discov', 'sign', 'on', 'the', 'door', 'state', 'thei', 'will', 'be', 'close', 'the', 'remaind', 'of', 'the', 'week', 'thi', 'time', 'check', 'their', 'facebook', 'and', 'there', 'wa', 'no', 'inform', 'regard', 'the', 'extend', 'closur', 'in', 'fact', 'it', 'wa', 'bit', 'confus', 'becaus', 'thei', 'had', 'post', 'advertis', 'the', 're', 'open', 'and', 'even', 'pictur', 'post', 'of', 'peopl', 'eat', 'there', 'for', 'brunch', 'event', 'just', 'the', 'other', 'dai', 'is', 'thi', 'some', 'kind', 'of', 'secret', 'societi', 'of', 'delici', 'eateri', 'realli', 'wish', 'knew', 'poor', 'commun', 'on', 'the', 'busi', 'side', 'of', 'thing', 'ha', 'made', 'me', 'feel', 'like', 'probabl', 'won', 'be', 'give', 'these', 'gui', 'try', 'if', 'do', 'muster', 'up', 'the', 'fortitud', 'to', 'drive', 'clear', 'across', 'town', 'again', 'will', 'definit', 'be', 'call', 'ahead', 'to', 'make', 'sure', 'thei', 'ar', 'open', 'suggest', 'you', 'do', 'the', 'same']
# [47, 60, 34, 3, 90, 17, 28, 13, 233, 33, 352, 51, 15, 29, 262, 1, 110, 33, 352, 51, 4, 173, 15, 21, 262, 7, 988, 51, 2, 47, 25, 230, 10, 1, 726, 240, 104, 938, 72, 30, 4, 57, 1718, 6, 17, 10, 52, 1026, 58, 22, 48, 3, 83, 76, 51, 2, 2766, 1, 109, 384, 1489, 15, 22, 199, 51, 10, 52, 2664, 2103, 56, 25, 262, 13, 183, 31, 365, 78, 20, 2664, 17, 4, 6, 57, 1894, 3, 40, 442, 2740, 726, 1329, 43, 1, 133, 102, 68, 3, 1489, 572, 10, 1, 335, 653, 15, 63, 25, 262, 1, 4702, 6, 1, 304, 17, 33, 186, 52, 2664, 2, 30, 4, 57, 638, 1758, 1, 2583, 9, 538, 5, 4, 187, 1008, 72, 15, 22, 881, 1205, 1, 157, 230, 2, 73, 895, 881, 6, 115, 113, 30, 7, 485, 744, 42, 1, 69, 117, 8, 17, 65, 284, 6, 2377, 4824, 6, 167, 2360, 60, 455, 746, 557, 1039, 10, 1, 179, 193, 6, 126, 100, 143, 40, 201, 34, 260, 344, 25, 134, 303, 295, 90, 36, 77, 51, 1, 3, 422, 858, 640, 415, 116, 63, 151, 25, 159, 948, 3, 92, 188, 15, 29, 230, 587, 19, 77, 1, 247]

# %%
print(padded_sequences[0])
# Out:
# [  15   29  262    1  110   33  352   51    4  173   15   21  262    7
#   988   51    2   47   25  230   10    1  726  240  104  938   72   30
#     4   57 1718    6   17   10   52 1026   58   22   48    3   83   76
#    51    2 2766    1  109  384 1489   15   22  199   51   10   52 2664
#  2103   56   25  262   13  183   31  365   78   20 2664   17    4    6
#    57 1894    3   40  442 2740  726 1329   43    1  133  102   68    3
#  1489  572   10    1  335  653   15   63   25  262    1 4702    6    1
#   304   17   33  186   52 2664    2   30    4   57  638 1758    1 2583
#     9  538    5    4  187 1008   72   15   22  881 1205    1  157  230
#     2   73  895  881    6  115  113   30    7  485  744   42    1   69
#   117    8   17   65  284    6 2377 4824    6  167 2360   60  455  746
#   557 1039   10    1  179  193    6  126  100  143   40  201   34  260
#   344   25  134  303  295   90   36   77   51    1    3  422  858  640
#   415  116   63  151   25  159  948    3   92  188   15   29  230  587
#    19   77    1  247]

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten

num_classes = len(label.unique())
window_sizes = [2, 3, 4, 5]
num_filters = 20
architecture = "CNN"
activation = "tanh"

if architecture == "LSTM":
    model = Sequential()
    model.add(Embedding(vocab_size, output_dim=30, input_length=maxlen))
    model.add(SpatialDropout1D(0.25))
    model.add(LSTM(64, activation=activation, dropout=0.5, recurrent_dropout=0.5))
    model.add(Dropout(0.2))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
else:
    model = Sequential()
    model.add(Embedding(vocab_size, output_dim=30, input_length=maxlen))
    model.add(SpatialDropout1D(0.25))
    model.add(Conv1D(num_filters, kernel_size=window_sizes[0], activation=activation))
    model.add(MaxPooling1D())
    for window_size in window_sizes[1:]:
        model.add(Conv1D(num_filters, kernel_size=window_size, activation=activation))
        model.add(MaxPooling1D())
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 200, 30)           803430
#
#  spatial_dropout1d (SpatialD  (None, 200, 30)          0
#  ropout1D)
#
#  conv1d (Conv1D)             (None, 199, 20)           1220
#
#  max_pooling1d (MaxPooling1D  (None, 99, 20)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 97, 20)            1220
#
#  max_pooling1d_1 (MaxPooling  (None, 48, 20)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 45, 20)            1620
#
#  max_pooling1d_2 (MaxPooling  (None, 22, 20)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 18, 20)            2020
#
#  max_pooling1d_3 (MaxPooling  (None, 9, 20)            0
#  1D)
#
#  flatten (Flatten)           (None, 180)               0
#
#  dropout (Dropout)           (None, 180)               0
#
#  dense (Dense)               (None, 3)                 543
#
# =================================================================
# Total params: 810,053
# Trainable params: 810,053
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3)
history = model.fit(padded_sequences,one_hot_labels,validation_split=0.2, epochs=20, batch_size=32, callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 600/600 [==============================] - 61s 92ms/step - loss: 0.9114 - accuracy: 0.5364 - val_loss: 0.7277 - val_accuracy: 0.6685
# Epoch 2/20
# 600/600 [==============================] - 14s 23ms/step - loss: 0.6737 - accuracy: 0.7012 - val_loss: 0.6650 - val_accuracy: 0.7002
# Epoch 3/20
# 600/600 [==============================] - 9s 15ms/step - loss: 0.5857 - accuracy: 0.7485 - val_loss: 0.6762 - val_accuracy: 0.7021
# Epoch 4/20
# 600/600 [==============================] - 8s 13ms/step - loss: 0.5228 - accuracy: 0.7844 - val_loss: 0.6785 - val_accuracy: 0.7088
# Epoch 5/20
# 600/600 [==============================] - 6s 10ms/step - loss: 0.4678 - accuracy: 0.8089 - val_loss: 0.7125 - val_accuracy: 0.7040

# %%
# Plot training and validation accuracy scores
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['accuracy', 'val_accuracy'], loc='upper left')
plt.show()

# %%
# Plot training and validation accuracy scores
plt.plot(history.history['loss'], label ='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.title('Model Accuracy')
plt.legend()
plt.show()

# %%
loss, accuracy = model.evaluate(test_padded_sequences, test_one_hot_labels)
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# 188/188 [==============================] - 1s 5ms/step - loss: 0.7080 - accuracy: 0.6990
# Accuracy: 69.90%

# %%
from sklearn.metrics import classification_report

# Make predictions using the trained model
y_pred = model.predict(test_padded_sequences)

# Convert the predictions from probabilities to class labels
y_pred = np.argmax(y_pred, axis=1)

# Print the classification report
print(classification_report(np.argmax(test_one_hot_labels, axis=1), y_pred))
# Out:
# 188/188 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.77      0.70      0.73      1955
#            1       0.59      0.62      0.60      2007
#            2       0.75      0.78      0.76      2038
#
#     accuracy                           0.70      6000
#    macro avg       0.70      0.70      0.70      6000
# weighted avg       0.70      0.70      0.70      6000
